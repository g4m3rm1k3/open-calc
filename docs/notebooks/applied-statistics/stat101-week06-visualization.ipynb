# %% [markdown]
# # STAT101 Week 6: Visualization
# Select visualization type by variable roles and message.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../../data/applied-statistics/study_hours_scores.csv')
plt.figure(figsize=(6,4))
plt.scatter(df['study_hours_per_week'], df['exam_score'])
plt.xlabel('Study hours/week')
plt.ylabel('Exam score')
plt.title('Study hours vs Exam score')
plt.show()

# %%
df['exam_score'].hist(bins=8, figsize=(6,4))
plt.title('Distribution of Exam Scores')
plt.xlabel('Exam score')
plt.ylabel('Frequency')
plt.show()
